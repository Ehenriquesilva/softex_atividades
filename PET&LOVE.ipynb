# %% [markdown]
# <a href="https://colab.research.google.com/github/Ehenriquesilva/softex_atividades/blob/main/PET%26LOVE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Algoritmo "PETLOVE_V2"
#
# var
#    CONTATO,CEP,CPF,CLIENTE,PETLOVE,PET,RACA:CARACTERE
#    SERVICO,PORTE,IDADE:INTEIRO
#    TOTAL:REAL
#
# PROCEDIMENTO TOPO()
# Inicio
#
#    ESCREVAL ("                                                       ")
#    ESCREVAL ("_______________________________________________________")
#    ESCREVAL ("____________                               ____________")
#    ESCREVAL ("____________  >>>> P E T  &  L O V E <<<<  ____________")
#    ESCREVAL ("_______________________________________________________")
#    ESCREVAL ("                                                       ")
# FIMPROCEDIMENTO
# INICIO
# TOPO()
#    ESCREVAL ("=======================================================")
#    ESCREVAL ("                      ORÇAMENTO                        ")
#    ESCREVAL ("=======================================================")
#    ESCREVAL ("CADASTRO DE CLIENTE")
#    ESCREVAL ("=======================================================")
#
#    ESCREVA ("FAVOR DIGITE SEU NOME:"                                  )
#      LEIA(CLIENTE)
#    ESCREVA ("INFORME SEU CEP:"                                        )
#      LEIA (CEP)
#    ESCREVA ("FORNEÇA OS DADOS DE SEU CPF:"                            )
#      LEIA (CPF)
#    ESCREVA ("DIGITE UM TELEFONE PARA CONTATO:"                        )
#      LEIA (CONTATO)
#
#    ESCREVAL ("=======================================================")
#    ESCREVAL ("CADASTRO DO PET")
#    ESCREVAL ("=======================================================")
#
#    ESCREVA ("INFORME O NOME DE SEU PET: "                             )
#      LEIA (PET)
#    ESCREVA ("INFORME A RAÇA DE SEU PET: "                             )
#      LEIA (RACA)
#    ESCREVA ("INFORME A IDADE DE SEU PET: "                            )
#      LEIA (IDADE)
#
#    ESCREVAL ("=======================================================")
#    ESCREVAL ("============ MONTE SEU PACOTE DE SERVIÇO ==============")
#    ESCREVAL ("=======================================================")
#
#    ESCREVAL (" DIGITE A OPÇÃO DE SERVIÇOS DESEJADAS"                  )
#    ESCREVAL (" [1] BANHO E TOSA COM MÁQUINA"                          )
#    ESCREVAL (" [2] BANHO E TOSA COM TESOURA"                          )
#    ESCREVAL ("=======================================================")
#    ESCREVAL (" OBS.ANTIPARASITÁRIO E ANTIPULGA SÃO INCLUSOS AO BANHO" )
#    ESCREVAL ("=======================================================")
#    ESCREVAL ("OPÇÃO DESEJADA"                                         )
#      LEIA (SERVICO)
#    ESCOLHA SERVICO
#         CASO 1
#       SERVICO <-80
#         CASO 2
#       SERVICO <-100
#       ESCREVAL (SERVICO)
#  FIMESCOLHA
#
#    ESCREVAL ("=======================================================")
#    ESCREVAL (" FINALIZE SEU ORÇAMENTO INFORMANDO O PORTE DE SEU PET"  )
#    ESCREVAL ("=======================================================")
#
#    ESCREVAL ("DIGITE O PORTE DE SEU PET"                              )
#    ESCREVAL (" [1] PEQUENO PORTE"                                     )
#    ESCREVAL (" [2] MÉDIO PORTE ADICIONAL DE R$20,00 "                 )
#    ESCREVAL (" [3] GRANDE PORTE ADICIONAL DE R$30,00 "                )
#    ESCREVAL ("  OPÇÃO DESEJADA"                                       )
#    ESCREVAL ("=======================================================")
#        LEIA (PORTE)
#    ESCOLHA PORTE
#          CASO 1
#       PORTE <-0
#          CASO 2
#       PORTE <-20
#          CASO 3
#       PORTE <-30
#
#  FIMESCOLHA
#  LIMPATELA
#  TOPO()
#      ESCREVAL("NOME DO CLIENTE: ", CLIENTE)
#      ESCREVAL("CEP: ", CEP)
#      ESCREVAL("CPF DO CLIENTE: ",CPF)
#      ESCREVAL("TELEFONE: ",CONTATO)
#      ESCREVAL("NOME DO PET: ",PET)
#      ESCREVAL("RAÇA DO PET: ",RACA)
#      ESCREVAL("IDADE DO PET: ",IDADE, " ANOS")
#
#
#  TOTAL <- (SERVICO + PORTE)
#  ESCREVAL ("TOTAL DO SERVIÇO É R$" , TOTAL,",00 REAIS")
#   SE SERVICO = 80 ENTAO
#          ESCREVAL("-REFERENTE AOS SERVIÇOS DE BANHO E TOSA COM MÁQUINA")
#          SENAO
#          ESCREVAL("-REFERENTE AOS SERVIÇOS DE BANHO E TOSA COM TESOURA")
#          FIMSE
#          SE PORTE = 0 ENTAO
#          ESCREVAL ("PARA ANIMAL DE PEQUENO PORTE.")
#          SENAO
#          SE  PORTE = 20 ENTAO
#          ESCREVAL ("PARA ANIMAL DE MÉDIO PORTE.")
#          SENAO
#          ESCREVAL ("PARA ANIMAL DE GRANDE PORTE.")
#   FIMSE
#
#  ESCREVAL ("                                                          ")
#  ESCREVAL ("                                                          ")
#  ESCREVAL ("                           ATÉ AQUI NOS AJUDOU O SENHOR !" )
#
# fimalgoritmo
