# %% [markdown]
# <a href="https://colab.research.google.com/github/Ehenriquesilva/softex_atividades/blob/main/BOMBA_!!!.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from time import sleep
for cont in range(10, -1, -1):
  print(cont)
  sleep(0.5)
print('BOM! BUM! BOM! GALVÃO GRITA É PENTA,É PENTA!!!')
